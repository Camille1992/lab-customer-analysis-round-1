# %%
import pandas as pd
import numpy as np

# %%
file1 = pd.read_csv('C:/Users/camil/Documents/Courses/Ironhack/Module 1/Week 2/Intro to Pandas/labs/lab-customer-analysis-round-1/files_for_lab/csv_files/file1.csv')
file2 = pd.read_csv('C:/Users/camil/Documents/Courses/Ironhack/Module 1/Week 2/Intro to Pandas/labs/lab-customer-analysis-round-1/files_for_lab/csv_files/file2.csv')
file3 = pd.read_csv('C:/Users/camil/Documents/Courses/Ironhack/Module 1/Week 2/Intro to Pandas/labs/lab-customer-analysis-round-1/files_for_lab/csv_files/file3.csv')

# %%
file1.shape
# Out:
# (4008, 11)

# %%
file2.shape
# Out:
# (996, 11)

# %%
file3.shape
# Out:
# (7070, 11)

# %%
file1.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
range(len(file1.columns))
# Out:
# range(0, 11)

# %%
cols1 = []

for i in range(len(file1.columns)):
    cols1.append(file1.columns[i].lower().replace(" ", "_"))

file1.columns = cols1
file1.head()
# Out:
#   customer          st gender             education customer_lifetime_value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly_premium_auto number_of_open_complaints     policy_type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle_class  total_claim_amount
# ...

# %%
file2.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
cols2 = []

for i in range(len(file2.columns)):
    cols2.append(file2.columns[i].lower().replace(" ", "_"))

file2.columns = cols2
file2.head()
# Out:
#   customer          st gender education customer_lifetime_value  income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    monthly_premium_auto number_of_open_complaints  total_claim_amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       policy_type  vehicle_class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
cols3 = []

for i in range(len(file3.columns)):
    cols3.append(file3.columns[i].lower().replace(" ", "_"))

file3.columns = cols3
file3.head()
# Out:
#   customer       state  customer_lifetime_value             education gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    income  monthly_premium_auto  number_of_open_complaints    policy_type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    total_claim_amount  vehicle_class
# ...

# %%
file1 = file1.rename(columns={'st':'state'})
file2 = file2.rename(columns={'st':'state'})
file1.head()
# Out:
#   customer       state gender             education customer_lifetime_value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly_premium_auto number_of_open_complaints     policy_type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle_class  total_claim_amount
# ...

# %%
file2.head()
# Out:
#   customer       state gender education customer_lifetime_value  income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    monthly_premium_auto number_of_open_complaints  total_claim_amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       policy_type  vehicle_class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
# re ordering columns
    # file2 -> 'total_claim_amount' needs to move at the end
    # file3 -> 'customer_lifetime_value; education; gender => gender; education; customer_lifetime_value
    #       -> 'total_claim_amount' needs to move at the end

# %%
file2 = file2.reindex(columns=['customer', 'state', 'gender', 'education', 'customer_lifetime_value', 'income', 'monthly_premium_auto', 'number_of_open_complaints', 'policy_type', 'vehicle_class', 'total_claim_amount'])
file3 = file3.reindex(columns=['customer', 'state', 'gender', 'education', 'customer_lifetime_value', 'income', 'monthly_premium_auto', 'number_of_open_complaints', 'policy_type', 'vehicle_class', 'total_claim_amount'])
file2.head()
# Out:
#   customer       state gender education customer_lifetime_value  income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    monthly_premium_auto number_of_open_complaints     policy_type  \
# 0                    88                    1/0/00   Personal Auto
# 1                   114                    1/0/00    Special Auto
# 2                   112                    1/0/00   Personal Auto
# 3                   214                    1/1/00   Personal Auto
# 4                    94                    1/0/00  Corporate Auto
#
#    vehicle_class  total_claim_amount
# 0  Four-Door Car               633.6
# 1            SUV               547.2
# ...

# %%
file3.head()
# Out:
#   customer       state gender             education  customer_lifetime_value  \
# 0  SA25987  Washington      M  High School or Below              3479.137523
# 1  TB86706     Arizona      M                Master              2502.637401
# 2  ZL73902      Nevada      F              Bachelor              3265.156348
# 3  KX23516  California      F  High School or Below              4455.843406
# 4  FN77294  California      M  High School or Below              7704.958480
#
#    income  monthly_premium_auto  number_of_open_complaints    policy_type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    vehicle_class  total_claim_amount
# ...

# %%
df = file1.copy()
df
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df = df.append([file2, file3])
df.shape
# Out:
# (12074, 11)

# %%
df = df.reset_index(drop=True)
df
# Out:
#       customer       state gender             education  \
# 0      RB50392  Washington    NaN                Master
# 1      QZ44356     Arizona      F              Bachelor
# 2      AI49188      Nevada      F              Bachelor
# 3      WW63253  California      M              Bachelor
# 4      GA49547  Washington      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316  California      M              Bachelor
# 12070  PK87824  California      F               College
# 12071  TD14365  California      M              Bachelor
# 12072  UP19263  California      M               College
# 12073  Y167826  California      M               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                         NaN      0.0                1000.0
# 1                  697953.59%      0.0                  94.0
# 2                 1288743.17%  48767.0                 108.0
# ...

# %%
df.dtypes
# income, monthly_premium_auto and total_claim_amount are numerical
# the rest are objects, categorical
# number_of_open_complaints is an object, should probably be a integer (or a float)
# Out:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer_lifetime_value       object
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object

# %%
df.select_dtypes(float)
# Out:
#         income  monthly_premium_auto  total_claim_amount
# 0          0.0                1000.0            2.704934
# 1          0.0                  94.0         1131.464935
# 2      48767.0                 108.0          566.472247
# 3          0.0                 106.0          529.881344
# 4      36357.0                  68.0           17.269323
# ...        ...                   ...                 ...
# 12069  71941.0                  73.0          198.234764
# 12070  21604.0                  79.0          379.200000
# 12071      0.0                  85.0          790.784983
# 12072  21941.0                  96.0          691.200000
# 12073      0.0                  77.0          369.600000
#
# [12074 rows x 3 columns]

# %%
df.select_dtypes(object)
# Out:
#       customer       state gender             education  \
# 0      RB50392  Washington    NaN                Master
# 1      QZ44356     Arizona      F              Bachelor
# 2      AI49188      Nevada      F              Bachelor
# 3      WW63253  California      M              Bachelor
# 4      GA49547  Washington      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316  California      M              Bachelor
# 12070  PK87824  California      F               College
# 12071  TD14365  California      M              Bachelor
# 12072  UP19263  California      M               College
# 12073  Y167826  California      M               College
#
#       customer_lifetime_value number_of_open_complaints     policy_type  \
# 0                         NaN                    1/0/00   Personal Auto
# 1                  697953.59%                    1/0/00   Personal Auto
# 2                 1288743.17%                    1/0/00   Personal Auto
# ...

# %%
# Understanding the meaning of the columns:

# customer -> car plate
# state -> where the car is registered
# gender -> gender of the owner
# education -> education of the owner
# customer_lifetime_value -> theoritical amount of the value the customer will bring to the company on the long-term
# income -> income brought by the customer to the company
# monthly_premium_auto -> the premium the customer is paying each month to the company
# number_of_open_complaints -> complaints, fines inputed to the customer's car
# policy_type -> nature of the contract, which depends on the nature of the client: personal or corporate
# vehicle_class -> nature of the vehicle, specified by number of doors

# %%
df.describe() # describing the data with stats
# Out:
#              income  monthly_premium_auto  total_claim_amount
# count   9137.000000           9137.000000         9137.000000
# mean   37828.820291            110.391266          430.527140
# std    30358.716159            581.376032          289.582968
# min        0.000000             61.000000            0.099007
# 25%        0.000000             68.000000          266.996814
# 50%    34244.000000             83.000000          377.561463
# 75%    62447.000000            109.000000          546.420009
# max    99981.000000          35354.000000         2893.239678

# %%
# Delete the column education and the number of open complaints from the dataframe.

df.drop(['education'],axis=1, inplace=True)

# %%
df.head()
# Out:
#   customer       state gender customer_lifetime_value   income  \
# 0  RB50392  Washington    NaN                     NaN      0.0
# 1  QZ44356     Arizona      F              697953.59%      0.0
# 2  AI49188      Nevada      F             1288743.17%  48767.0
# 3  WW63253  California      M              764586.18%      0.0
# 4  GA49547  Washington      M              536307.65%  36357.0
#
#    monthly_premium_auto number_of_open_complaints     policy_type  \
# 0                1000.0                    1/0/00   Personal Auto
# 1                  94.0                    1/0/00   Personal Auto
# 2                 108.0                    1/0/00   Personal Auto
# 3                 106.0                    1/0/00  Corporate Auto
# 4                  68.0                    1/0/00   Personal Auto
#
#    vehicle_class  total_claim_amount
# 0  Four-Door Car            2.704934
# 1  Four-Door Car         1131.464935
# 2   Two-Door Car          566.472247
# ...

# %%
# Check for duplicate rows in the data and remove if any.

df = df.drop_duplicates()
df
# Out:
#       customer       state gender customer_lifetime_value   income  \
# 0      RB50392  Washington    NaN                     NaN      0.0
# 1      QZ44356     Arizona      F              697953.59%      0.0
# 2      AI49188      Nevada      F             1288743.17%  48767.0
# 3      WW63253  California      M              764586.18%      0.0
# 4      GA49547  Washington      M              536307.65%  36357.0
# ...        ...         ...    ...                     ...      ...
# 12069  LA72316  California      M             23405.98798  71941.0
# 12070  PK87824  California      F             3096.511217  21604.0
# 12071  TD14365  California      M             8163.890428      0.0
# 12072  UP19263  California      M             7524.442436  21941.0
# 12073  Y167826  California      M             2611.836866      0.0
#
#        monthly_premium_auto number_of_open_complaints     policy_type  \
# 0                    1000.0                    1/0/00   Personal Auto
# ...

# %%
# Filter out the data for customers who have an income of 0 or less.

df.isnull().any()
# Out:
# customer                     True
# state                        True
# gender                       True
# customer_lifetime_value      True
# income                       True
# monthly_premium_auto         True
# number_of_open_complaints    True
# policy_type                  True
# vehicle_class                True
# total_claim_amount           True
# dtype: bool

# %%
df.index[df.isnull().any(axis=1)]
# Out:
# Int64Index([   0,   11,   12,   13,   14,   15,   16,   17,   18,   19,
#             ...
#              988, 1071, 4175, 4236, 4265, 4333, 4380, 4588, 4869, 4988],
#            dtype='int64', length=128)

# %%
df['income'].index[df.isnull().any(axis=1)]
# Out:
# Int64Index([   0,   11,   12,   13,   14,   15,   16,   17,   18,   19,
#             ...
#              988, 1071, 4175, 4236, 4265, 4333, 4380, 4588, 4869, 4988],
#            dtype='int64', length=128)

# %%
dftst = df.copy()
df_0 = dftst.index[dftst.isnull().any(axis=1)]
df_0.shape
# Out:
# (128,)

# %%
dftst.shape
# Out:
# (9135, 10)

# %%
dftst.drop(df_0,0,inplace=True)
dftst.shape
# C:\Users\camil\AppData\Local\Temp/ipykernel_15044/2532332584.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# dftst.drop(df_0,0,inplace=True)
# Out:
# C:\Users\camil\AppData\Local\Temp/ipykernel_10316/1191076115.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   dftst.drop(df_0,0,inplace=True)
# (9007, 10)

# %%
dftst
# still income with 0, doesn't work
# Out:
#       customer       state gender customer_lifetime_value   income  \
# 1      QZ44356     Arizona      F              697953.59%      0.0
# 2      AI49188      Nevada      F             1288743.17%  48767.0
# 3      WW63253  California      M              764586.18%      0.0
# 4      GA49547  Washington      M              536307.65%  36357.0
# 5      OC83172      Oregon      F              825629.78%  62902.0
# ...        ...         ...    ...                     ...      ...
# 12069  LA72316  California      M             23405.98798  71941.0
# 12070  PK87824  California      F             3096.511217  21604.0
# 12071  TD14365  California      M             8163.890428      0.0
# 12072  UP19263  California      M             7524.442436  21941.0
# 12073  Y167826  California      M             2611.836866      0.0
#
#        monthly_premium_auto number_of_open_complaints     policy_type  \
# 1                      94.0                    1/0/00   Personal Auto
# ...

# %%
# Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type.
dfx = df.copy()

dfx['customer_lifetime_value'] = pd.to_numeric(dfx["customer_lifetime_value"], errors='coerce')
dfx.dtypes
# Out:
# customer                      object
# state                         object
# gender                        object
# customer_lifetime_value      float64
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object

# %%
dfx["customer_lifetime_value"] = dfx['customer_lifetime_value'].apply(lambda x: x*100)
dfx
# changing the type as put the values with "%" as NaN, is it possible to create a function that removes the % and does *100 to the ones that don't have the%, then we don't loose too much data?
# Out:
#       customer       state gender  customer_lifetime_value   income  \
# 0      RB50392  Washington    NaN                      NaN      0.0
# 1      QZ44356     Arizona      F                      NaN      0.0
# 2      AI49188      Nevada      F                      NaN  48767.0
# 3      WW63253  California      M                      NaN      0.0
# 4      GA49547  Washington      M                      NaN  36357.0
# ...        ...         ...    ...                      ...      ...
# 12069  LA72316  California      M             2.340599e+06  71941.0
# 12070  PK87824  California      F             3.096511e+05  21604.0
# 12071  TD14365  California      M             8.163890e+05      0.0
# 12072  UP19263  California      M             7.524442e+05  21941.0
# 12073  Y167826  California      M             2.611837e+05      0.0
#
#        monthly_premium_auto number_of_open_complaints     policy_type  \
# 0                    1000.0                    1/0/00   Personal Auto
# ...
